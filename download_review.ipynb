# %% [markdown]
# # ICLR Data Download Tool
#
# This notebook is used to download papers and review data from the ICLR conference.
#
# Features:
# - Download ICLR paper PDFs for specified years
# - Retrieve official reviews for papers
# - Save data in CSV format

# %% [markdown]
# ## 1. Install Dependencies

# %%
# %pip install openreview-py requests
# Out:
# Collecting openreview-py
#   Downloading openreview_py-1.53.3-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Collecting pycryptodome (from openreview-py)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from openreview-py) (1.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openreview-py) (4.67.1)
# Collecting Deprecated (from openreview-py)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Collecting pylatexenc (from openreview-py)
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting tld>=0.12 (from openreview-py)
#   Downloading tld-0.13.1-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.12/dist-packages (from openreview-py) (2.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openreview-py) (2.0.2)
# Collecting litellm==1.76.1 (from openreview-py)
#   Downloading litellm-1.76.1-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (3.13.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (8.3.0)
# Collecting fastuuid>=0.12.0 (from litellm==1.76.1->openreview-py)
#   Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (0.28.1)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (8.7.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (3.1.6)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (4.25.1)
# Requirement already satisfied: openai>=1.99.5 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (1.109.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (2.11.10)
# Requirement already satisfied: python-dotenv>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (1.2.1)
# Requirement already satisfied: tiktoken>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (0.12.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from litellm==1.76.1->openreview-py) (0.22.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from Deprecated->openreview-py) (2.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm==1.76.1->openreview-py) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm==1.76.1->openreview-py) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm==1.76.1->openreview-py) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm==1.76.1->openreview-py) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm==1.76.1->openreview-py) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm==1.76.1->openreview-py) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10->litellm==1.76.1->openreview-py) (1.22.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm==1.76.1->openreview-py) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->litellm==1.76.1->openreview-py) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->litellm==1.76.1->openreview-py) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.8.0->litellm==1.76.1->openreview-py) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.76.1->openreview-py) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.76.1->openreview-py) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.76.1->openreview-py) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.76.1->openreview-py) (0.28.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm==1.76.1->openreview-py) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm==1.76.1->openreview-py) (0.11.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm==1.76.1->openreview-py) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.5->litellm==1.76.1->openreview-py) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm==1.76.1->openreview-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm==1.76.1->openreview-py) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.5.0->litellm==1.76.1->openreview-py) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.7.0->litellm==1.76.1->openreview-py) (2024.11.6)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers->litellm==1.76.1->openreview-py) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.76.1->openreview-py) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.76.1->openreview-py) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.76.1->openreview-py) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.76.1->openreview-py) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.76.1->openreview-py) (1.2.0)
# Downloading openreview_py-1.53.3-py3-none-any.whl (885 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 885.2/885.2 kB 24.5 MB/s eta 0:00:00
# Downloading litellm-1.76.1-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 95.1 MB/s eta 0:00:00
# Downloading tld-0.13.1-py2.py3-none-any.whl (274 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 16.6 MB/s eta 0:00:00
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 71.3 MB/s eta 0:00:00
# Downloading fastuuid-0.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.1/278.1 kB 15.9 MB/s eta 0:00:00
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=30b3b6ef4b7297b3c0db68bf2a9bea910e3db5cfe0748763dc484605362162e9
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, tld, pycryptodome, fastuuid, Deprecated, litellm, openreview-py
# Successfully installed Deprecated-1.3.1 fastuuid-0.14.0 litellm-1.76.1 openreview-py-1.53.3 pycryptodome-3.23.0 pylatexenc-2.10 tld-0.13.1

# %% [markdown]
# ## 2. Import Libraries

# %%
import openreview
import requests
import os
import csv
import time
from pathlib import Path

# %% [markdown]
# ## 3. Mount Google Drive
#
# **Important**: Run this cell to connect to Google Drive. Data will be saved to your Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Create project working directory
import os
WORK_DIR = '/content/drive/MyDrive/Notebooks/AI_review'
os.makedirs(WORK_DIR, exist_ok=True)
print(f"✓ Google Drive mounted")
print(f"✓ Working directory: {WORK_DIR}")
print(f"All data will be saved to this directory")
# Out:
# Mounted at /content/drive
# ✓ Google Drive mounted
# ✓ Working directory: /content/drive/MyDrive/Notebooks/AI_review
# All data will be saved to this directory

# %% [markdown]
# ## 4. Define Download Function

# %%
def download_iclr_data(year, max_papers, work_dir='/content/drive/MyDrive/Notebooks/AI_review'):
    """
    Download ICLR papers and review data for a given year

    Args:
        year: Year of the conference
        max_papers: Maximum number of papers to download. None means download all.
        work_dir: Working directory (default: Google Drive)
    """
    OUTPUT_DIR = os.path.join(work_dir, f'iclr_{year}_data')
    PDF_DIR = os.path.join(OUTPUT_DIR, 'pdfs')
    CSV_FILE = os.path.join(OUTPUT_DIR, f'iclr_{year}_reviews.csv')

    # Create output directory
    os.makedirs(PDF_DIR, exist_ok=True)

    # Use API v2 for 2024 and later; otherwise, use API v1
    use_api_v2 = (year >= 2024)

    # Initialize OpenReview client
    if use_api_v2:
        client = openreview.api.OpenReviewClient(baseurl='https://api2.openreview.net')
    else:
        client = openreview.Client(baseurl='https://api.openreview.net')

    # Retrieve ICLR papers
    venue_id = f'ICLR.cc/{year}/Conference'
    print(f"\n{'='*80}")
    print(f"Fetching data for {venue_id}... (API {'v2' if use_api_v2 else 'v1'})")
    print(f"{'='*80}")

    try:
        if use_api_v2:
            # API v2 uses a different invitation
            submissions = client.get_all_notes(
                invitation=f'{venue_id}/-/Submission'
            )
        else:
            submissions = client.get_all_notes(
                invitation=f'{venue_id}/-/Blind_Submission',
                details='replyCount,writable'
            )
    except Exception as e:
        print(f"✗ Failed to fetch submissions: {e}")
        return

    total_papers = len(submissions)
    papers_to_process = submissions[:max_papers] if max_papers else submissions

    print(f"Found {total_papers} papers in total")
    print(f"Processing {len(papers_to_process)} papers")
    print(f"Output directory: {OUTPUT_DIR}")

    # Prepare CSV data
    csv_data = []

    # Process each paper
    for idx, paper in enumerate(papers_to_process, 1):
        paper_id = paper.id

        # Note: API v2 'content' has nested 'value'; API v1 structure is flat
        if use_api_v2:
            title = paper.content.get('title', {}).get('value', 'No Title')
            authors = paper.content.get('authors', {}).get('value', [])
            abstract = paper.content.get('abstract', {}).get('value', '')
            keywords = paper.content.get('keywords', {}).get('value', [])
            # API v2 may not have direct 'pdf' field
            pdf_path = ''
        else:
            title = paper.content.get('title', 'No Title')
            authors = paper.content.get('authors', [])
            abstract = paper.content.get('abstract', '')
            keywords = paper.content.get('keywords', [])
            pdf_path = paper.content.get('pdf', '')

        print(f"\n[{idx}/{len(papers_to_process)}] Processing paper: {title[:60]}...")

        # 1. Download PDF
        pdf_filename = ''
        pdf_url = None

        if use_api_v2:
            # API v2: build PDF URL from paper ID
            pdf_url = f'https://openreview.net/pdf?id={paper_id}'
            pdf_filename = os.path.join(PDF_DIR, f'{paper_id}.pdf')
        elif pdf_path:
            # API v1: use 'pdf' field from content
            pdf_url = f'https://openreview.net{pdf_path}'
            pdf_filename = os.path.join(PDF_DIR, f'{paper_id}.pdf')

        if pdf_url:
            try:
                if not os.path.exists(pdf_filename):
                    print(f"  - Downloading PDF...")
                    response = requests.get(pdf_url, timeout=30)
                    if response.status_code == 200:
                        with open(pdf_filename, 'wb') as f:
                            f.write(response.content)
                        print(f"    ✓ PDF saved")
                    else:
                        print(f"    ✗ PDF download failed: HTTP {response.status_code}")
                        pdf_filename = ''
                else:
                    print(f"  - PDF already exists, skipping download")
            except Exception as e:
                print(f"    ✗ PDF download error: {e}")
                pdf_filename = ''

        # 2. Get official reviews
        print(f"  - Fetching reviews...")
        try:
            if use_api_v2:
                # API v2: get reviews via invitation
                reviews = client.get_all_notes(
                    forum=paper_id,
                    invitation=f'{venue_id}/Submission{paper.number}/-/Official_Review'
                )
            else:
                # API v1: fetch all notes and filter for Official_Review
                all_notes = client.get_all_notes(forum=paper_id)
                reviews = [note for note in all_notes if 'Official_Review' in note.invitation]

            print(f"    Found {len(reviews)} official reviews")

            # 3. Save each review to CSV
            if reviews:
                for review_idx, review in enumerate(reviews, 1):
                    # Field names differ by year; try several possibilities
                    if use_api_v2:
                        # API v2: content.field.value
                        review_text = (
                            review.content.get('review', {}).get('value') or
                            review.content.get('main_review', {}).get('value') or
                            review.content.get('summary', {}).get('value') or
                            review.content.get('strengths_and_weaknesses', {}).get('value') or
                            ''
                        )
                        rating = (
                            review.content.get('rating', {}).get('value') or
                            review.content.get('recommendation', {}).get('value') or
                            ''
                        )
                    else:
                        # API v1: content.field is value directly
                        review_text = (
                            review.content.get('review') or  # 2020, 2021
                            review.content.get('main_review') or  # 2022
                            review.content.get('strength_and_weaknesses') or  # 2023
                            review.content.get('summary_of_the_review') or  # alternative
                            ''
                        )
                        rating = (
                            review.content.get('rating') or  # 2020, 2021
                            review.content.get('recommendation') or  # 2022, 2023
                            ''
                        )

                    review_data = {
                        'paper_title': title,
                        'review_text': review_text,
                        'pdf_path': pdf_filename,
                    }
                    csv_data.append(review_data)
                    print(f"      Review {review_idx}: rating={rating}")
            else:
                # If no reviews found, at least save paper info
                csv_data.append({
                    'paper_title': title,
                    'review_text': '',
                    'pdf_path': pdf_filename,
                })
        except Exception as e:
            print(f"    ✗ Error fetching reviews: {e}")

        # Avoid sending requests too quickly
        time.sleep(0.5)

    # 4. Save to CSV file
    print(f"\n{'='*80}")
    print(f"Saving data to CSV: {CSV_FILE}")

    if csv_data:
        fieldnames = ['paper_title', 'review_text', 'pdf_path']

        with open(CSV_FILE, 'w', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=fieldnames)
            writer.writeheader()
            writer.writerows(csv_data)

        print(f"✓ Successfully saved {len(csv_data)} records")
        print(f"✓ PDFs are saved in: {PDF_DIR}")
        print(f"✓ CSV file saved at: {CSV_FILE}")
    else:
        print("No data to save")

    print("="*80)

# %% [markdown]
# ## 5. Configure Parameters and Run
#
# Modify the parameters below to set the years and number of papers to download

# %%
# Configure parameters
YEARS = [2021, 2022, 2023]  # List of years to download, can set multiple, e.g., [2020, 2021, 2022]
NUM_PAPERS = 100  # Number of papers to download per year, set to None to download all papers
# NUM_PAPERS = None

print("="*80)
print(f"Starting download of ICLR papers and reviews for years: {YEARS}")
print(f"Save location: {WORK_DIR}")
if NUM_PAPERS:
    print(f"Downloading {NUM_PAPERS} papers per year")
else:
    print(f"Downloading all papers per year")
print("="*80)

for year in YEARS:
    try:
        download_iclr_data(year, NUM_PAPERS, WORK_DIR)
    except Exception as e:
        print(f"\n✗ Download failed for year {year}: {e}")
        continue

print("\n" + "="*80)
print("All requested years downloaded successfully!")
print(f"Files saved to Google Drive: {WORK_DIR}")
print("="*80)
# Out:
# ================================================================================
# Starting download of ICLR papers and reviews for years: [2021, 2022, 2023]
# Save location: /content/drive/MyDrive/Notebooks/AI_review
# Downloading 100 papers per year
# ================================================================================
#
# ================================================================================
# Fetching data for ICLR.cc/2021/Conference... (API v1)
# ================================================================================
# Getting V1 Notes: 100%|█████████▉| 2591/2594 [00:02<00:00, 1265.79it/s]
# Found 2594 papers in total
# Processing 100 papers
# Output directory: /content/drive/MyDrive/Notebooks/AI_review/iclr_2021_data
#
# [1/100] Processing paper: Contextual Transformation Networks for Online Continual Lear...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [2/100] Processing paper: Retrieval-Augmented Generation for Code Summarization via Hy...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=7: Good paper, accept
#
# [3/100] Processing paper: Breaking the Expressive Bottlenecks of Graph Neural Networks...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#       Review 5: rating=6: Marginally above acceptance threshold
#
# [4/100] Processing paper: Cross-Modal Retrieval Augmentation for Multi-Modal Classific...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=3: Clear rejection
#
# [5/100] Processing paper: Poisoned classifiers are not only backdoored, they are funda...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=2: Strong rejection
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=7: Good paper, accept
#
# [6/100] Processing paper: Behavioral Cloning from Noisy Demonstrations...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=7: Good paper, accept
#
# [7/100] Processing paper: Latent Programmer: Discrete Latent Codes for Program Synthes...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=3: Clear rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=7: Good paper, accept
#
# [8/100] Processing paper: UserBERT: Self-supervised User Representation Learning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=3: Clear rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [9/100] Processing paper: Are all outliers alike?  On Understanding the Diversity of O...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [10/100] Processing paper: Differentially Private Generative Models Through Optimal Tra...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=6: Marginally above acceptance threshold
#
# [11/100] Processing paper: Learning the Connections in Direct Feedback Alignment...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#
# [12/100] Processing paper: Generative Adversarial User Privacy in Lossy Single-Server I...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#
# [13/100] Processing paper: Information Theoretic Regularization for Learning Global Fea...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#
# [14/100] Processing paper: Approximate Nearest Neighbor Negative Contrastive Learning f...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=9: Top 15% of accepted papers, strong accept
#
# [15/100] Processing paper: A Policy Gradient Algorithm for Learning to Learn in Multiag...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [16/100] Processing paper: Better Optimization can Reduce Sample Complexity: Active Sem...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [17/100] Processing paper: On interaction between augmentations and corruptions in natu...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [18/100] Processing paper: An information-theoretic framework for learning models of in...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=5: Marginally below acceptance threshold
#
# [19/100] Processing paper: Fast Geometric Projections for Local Robustness Certificatio...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=8: Top 50% of accepted papers, clear accept
#       Review 4: rating=7: Good paper, accept
#
# [20/100] Processing paper: Improving Mutual Information based Feature Selection by Boos...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=2: Strong rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [21/100] Processing paper: A Unified Framework for Convolution-based Graph Neural Netwo...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [22/100] Processing paper: Improving Adversarial Robustness via Channel-wise Activation...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=8: Top 50% of accepted papers, clear accept
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=7: Good paper, accept
#
# [23/100] Processing paper: Self-Supervised Variational Auto-Encoders...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [24/100] Processing paper: Variational Structured Attention Networks for Dense Pixel-Wi...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [25/100] Processing paper: Feature-Robust Optimal Transport for High-Dimensional Data...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=3: Clear rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#
# [26/100] Processing paper: On the Importance of Looking at the Manifold...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=3: Clear rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [27/100] Processing paper: Fuzzy Tiling Activations: A Simple Approach to Learning Spar...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=7: Good paper, accept
#
# [28/100] Processing paper: GAN "Steerability" without optimization ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=8: Top 50% of accepted papers, clear accept
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=8: Top 50% of accepted papers, clear accept
#
# [29/100] Processing paper: Response Modeling of Hyper-Parameters for Deep Convolutional...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
# Retrying request: GET /notes?forum=zCu1BZYCueE&limit=1000&sort=id, response: <urllib3.response.HTTPResponse object at 0x7c63ae0f67d0>, error: None
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [30/100] Processing paper: Statistical inference for individual fairness...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#
# [31/100] Processing paper: More or Less: When and How to Build Convolutional Neural Net...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=8: Top 50% of accepted papers, clear accept
#       Review 4: rating=8: Top 50% of accepted papers, clear accept
#
# [32/100] Processing paper: AN ONLINE SEQUENTIAL TEST FOR QUALITATIVE TREATMENT EFFECTS...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=3: Clear rejection
#
# [33/100] Processing paper: Graph Joint Attention Networks...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [34/100] Processing paper: Improving Model Robustness with Latent Distribution Locally ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=7: Good paper, accept
#
# [35/100] Processing paper: You Only Need Adversarial Supervision for Semantic Image Syn...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=7: Good paper, accept
#
# [36/100] Processing paper: Towards Powerful Graph Neural Networks: Diversity Matters...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=3: Clear rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#       Review 5: rating=4: Ok but not good enough - rejection
#
# [37/100] Processing paper: Deep Clustering and Representation Learning that Preserves G...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [38/100] Processing paper: Is deeper better? It depends on locality of relevant feature...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [39/100] Processing paper: Fast 3D Acoustic Scattering via Discrete Laplacian Based Imp...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=3: Clear rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#
# [40/100] Processing paper: Attainability and Optimality: The Equalized-Odds Fairness Re...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#       Review 5: rating=5: Marginally below acceptance threshold
#
# [41/100] Processing paper: Regularization Matters in Policy Optimization - An Empirical...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=7: Good paper, accept
#
# [42/100] Processing paper: Learning Hyperbolic Representations of Topological Features...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [43/100] Processing paper: A Deeper Look at Discounting Mismatch in Actor-Critic Algori...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [44/100] Processing paper: TOMA: Topological Map Abstraction for Reinforcement Learning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=3: Clear rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [45/100] Processing paper: Novelty Detection via Robust Variational Autoencoding...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [46/100] Processing paper: Regression Prior Networks...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [47/100] Processing paper: Localized Meta-Learning: A PAC-Bayes Analysis for Meta-Learn...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [48/100] Processing paper: Attention-Based Clustering: Learning a Kernel from Context...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [49/100] Processing paper: Reverse engineering learned optimizers reveals known and nov...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=8: Top 50% of accepted papers, clear accept
#
# [50/100] Processing paper: Do Transformers Understand Polynomial Simplification? ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [51/100] Processing paper: Are all negatives created equal in contrastive instance disc...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=2: Strong rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [52/100] Processing paper: Image GANs meet Differentiable Rendering for Inverse Graphic...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=8: Top 50% of accepted papers, clear accept
#       Review 3: rating=6: Marginally above acceptance threshold
#
# [53/100] Processing paper: Does enhanced shape bias improve neural network robustness t...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=9: Top 15% of accepted papers, strong accept
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [54/100] Processing paper: Catastrophic Fisher Explosion: Early Phase Fisher Matrix Imp...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [55/100] Processing paper: Joint Learning of Full-structure Noise in Hierarchical Bayes...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [56/100] Processing paper: Block Skim Transformer for Efficient Question Answering...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [57/100] Processing paper: Explicit Connection Distillation...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [58/100] Processing paper: Dual Graph Complementary Network...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=2: Strong rejection
#       Review 4: rating=3: Clear rejection
#
# [59/100] Processing paper: Adaptive Learning Rates for Multi-Agent Reinforcement Learni...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
# Retrying request: GET /notes?forum=yN18f9V1Onp&limit=1000&sort=id, response: <urllib3.response.HTTPResponse object at 0x7c63ae0f7400>, error: None
#     Found 5 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#       Review 5: rating=5: Marginally below acceptance threshold
#
# [60/100] Processing paper: Optimal Neural Program Synthesis from Multimodal Specificati...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=7: Good paper, accept
#
# [61/100] Processing paper: Federated Learning's Blessing: FedAvg has Linear Speedup...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [62/100] Processing paper: BUSTLE: Bottom-Up Program Synthesis Through Learning-Guided ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=9: Top 15% of accepted papers, strong accept
#
# [63/100] Processing paper: Semi-supervised Keypoint Localization...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [64/100] Processing paper: Class Balancing GAN with a Classifier in the Loop...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [65/100] Processing paper: Generalizing Graph Convolutional Networks via Heat Kernel...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [66/100] Processing paper: A law of robustness for two-layers neural networks...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=7: Good paper, accept
#
# [67/100] Processing paper: Imagine That! Leveraging Emergent Affordances for 3D Tool Sy...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [68/100] Processing paper: Learning Monotonic Alignments with Source-Aware GMM Attentio...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [69/100] Processing paper: Private Image Reconstruction from System Side Channels Using...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=7: Good paper, accept
#
# [70/100] Processing paper: IEPT: Instance-Level and Episode-Level Pretext Tasks for Few...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=8: Top 50% of accepted papers, clear accept
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=7: Good paper, accept
#       Review 5: rating=5: Marginally below acceptance threshold
#
# [71/100] Processing paper: Learning Causal Semantic Representation for Out-of-Distribut...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=5: Marginally below acceptance threshold
#
# [72/100] Processing paper: Ensemble-based Adversarial Defense Using Diversified Distanc...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [73/100] Processing paper: Rewriting by Generating: Learn Heuristics for Large-scale Ve...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [74/100] Processing paper: Correcting experience replay for multi-agent communication...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=8: Top 50% of accepted papers, clear accept
#
# [75/100] Processing paper: Communication-Efficient Sampling for Distributed Training of...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [76/100] Processing paper: Making Coherence Out of Nothing At All: Measuring Evolution ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [77/100] Processing paper: Learning Visual Representations for Transfer Learning by Sup...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=7: Good paper, accept
#
# [78/100] Processing paper: Domain-Free Adversarial Splitting for Domain Generalization...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=5: Marginally below acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [79/100] Processing paper: Randomized Automatic Differentiation...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: Top 50% of accepted papers, clear accept
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=8: Top 50% of accepted papers, clear accept
#
# [80/100] Processing paper: Self-supervised Visual Reinforcement Learning with Object-ce...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=8: Top 50% of accepted papers, clear accept
#       Review 4: rating=9: Top 15% of accepted papers, strong accept
#
# [81/100] Processing paper: Rethinking Embedding Coupling in Pre-trained Language Models...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [82/100] Processing paper: Stochastic Normalized Gradient Descent with Momentum for Lar...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=3: Clear rejection
#
# [83/100] Processing paper: Multiscale Score Matching for Out-of-Distribution Detection...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=9: Top 15% of accepted papers, strong accept
#
# [84/100] Processing paper: An Adversarial Attack via Feature Contributive Regions...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=3: Clear rejection
#       Review 3: rating=3: Clear rejection
#
# [85/100] Processing paper: Clairvoyance: A Pipeline Toolkit for Medical Time Series...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=8: Top 50% of accepted papers, clear accept
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [86/100] Processing paper: Entropic gradient descent algorithms and wide flat minima...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [87/100] Processing paper: Monotonic neural network: combining deep learning with domai...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=2: Strong rejection
#       Review 2: rating=3: Clear rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=3: Clear rejection
#
# [88/100] Processing paper: On Dyadic Fairness: Exploring and Mitigating Bias in Graph C...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [89/100] Processing paper: Can a Fruit Fly Learn Word Embeddings?...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
# Retrying request: GET /notes?forum=xfmSoxdxFCG&limit=1000&sort=id, response: <urllib3.response.HTTPResponse object at 0x7c63ae0f5990>, error: None
#     Found 3 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=7: Good paper, accept
#
# [90/100] Processing paper: Empirical Frequentist Coverage of Deep Learning Uncertainty ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=3: Clear rejection
#       Review 4: rating=4: Ok but not good enough - rejection
#
# [91/100] Processing paper: Inductive Collaborative Filtering via Relation Graph Learnin...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [92/100] Processing paper: Hidden Markov models are recurrent neural networks: A diseas...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=3: Clear rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [93/100] Processing paper: Debiased Graph Neural Networks with Agnostic Label Selection...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=8: Top 50% of accepted papers, clear accept
#       Review 3: rating=4: Ok but not good enough - rejection
#       Review 4: rating=5: Marginally below acceptance threshold
#
# [94/100] Processing paper: Counterfactual Thinking for Long-tailed Information Extracti...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=3: Clear rejection
#       Review 4: rating=7: Good paper, accept
#
# [95/100] Processing paper: Isotropy in the Contextual Embedding Space: Clusters and Man...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=7: Good paper, accept
#       Review 2: rating=7: Good paper, accept
#       Review 3: rating=7: Good paper, accept
#
# [96/100] Processing paper: Class2Simi: A New Perspective on Learning with Label Noise...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=3: Clear rejection
#       Review 4: rating=3: Clear rejection
#       Review 5: rating=6: Marginally above acceptance threshold
#
# [97/100] Processing paper: Data augmentation as stochastic optimization...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: Marginally below acceptance threshold
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=7: Good paper, accept
#       Review 4: rating=6: Marginally above acceptance threshold
#
# [98/100] Processing paper: Shuffle to Learn: Self-supervised learning from permutations...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=4: Ok but not good enough - rejection
#       Review 2: rating=4: Ok but not good enough - rejection
#       Review 3: rating=4: Ok but not good enough - rejection
#
# [99/100] Processing paper: LambdaNetworks: Modeling long-range Interactions without Att...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=6: Marginally above acceptance threshold
#       Review 2: rating=6: Marginally above acceptance threshold
#       Review 3: rating=6: Marginally above acceptance threshold
#       Review 4: rating=6: Marginally above acceptance threshold
#       Review 5: rating=8: Top 50% of accepted papers, clear accept
#
# [100/100] Processing paper: Finding Patient Zero: Learning Contagion Source with Graph N...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=3: Clear rejection
#       Review 2: rating=5: Marginally below acceptance threshold
#       Review 3: rating=3: Clear rejection
#       Review 4: rating=7: Good paper, accept
#
# ================================================================================
# Saving data to CSV: /content/drive/MyDrive/Notebooks/AI_review/iclr_2021_data/iclr_2021_reviews.csv
# ✓ Successfully saved 388 records
# ✓ PDFs are saved in: /content/drive/MyDrive/Notebooks/AI_review/iclr_2021_data/pdfs
# ✓ CSV file saved at: /content/drive/MyDrive/Notebooks/AI_review/iclr_2021_data/iclr_2021_reviews.csv
# ================================================================================
#
# ================================================================================
# Fetching data for ICLR.cc/2022/Conference... (API v1)
# ================================================================================
# Getting V1 Notes: 100%|█████████▉| 2614/2617 [00:02<00:00, 1112.16it/s]
# Found 2617 papers in total
# Processing 100 papers
# Output directory: /content/drive/MyDrive/Notebooks/AI_review/iclr_2022_data
#
# [1/100] Processing paper: A Theory of Tournament Representations...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [2/100] Processing paper: Revisiting Design Choices in Offline Model Based Reinforceme...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=8: accept, good paper
#       Review 4: rating=8: accept, good paper
#       Review 5: rating=6: marginally above the acceptance threshold
#
# [3/100] Processing paper: To Impute or Not To Impute? Missing Data in Treatment Effect...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=3: reject, not good enough
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=5: marginally below the acceptance threshold
#
# [4/100] Processing paper: Learning and controlling the source-filter representation of...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [5/100] Processing paper: Self-Joint Supervised Learning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=8: accept, good paper
#       Review 3: rating=8: accept, good paper
#
# [6/100] Processing paper: How Does the Task Landscape Affect MAML Performance?...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [7/100] Processing paper: GrASP: Gradient-Based Affordance Selection for Planning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [8/100] Processing paper: On the benefits of maximum likelihood estimation for Regress...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=8: accept, good paper
#
# [9/100] Processing paper: Supervision Exists Everywhere: A Data Efficient Contrastive ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=8: accept, good paper
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [10/100] Processing paper: Generalized rectifier wavelet covariance models for texture ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=8: accept, good paper
#       Review 4: rating=8: accept, good paper
#
# [11/100] Processing paper: Adaptive Q-learning for Interaction-Limited Reinforcement Le...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=3: reject, not good enough
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [12/100] Processing paper: TransSlowDown: Efficiency Attacks on Neural Machine Translat...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=3: reject, not good enough
#
# [13/100] Processing paper: How Much Can CLIP Benefit Vision-and-Language Tasks?...
#   - Downloading PDF...
#     ✓ PDF saved
# ...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=8: accept, good paper
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [65/100] Processing paper: Minimum Curvature Manifold Learning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=5: marginally below the acceptance threshold
#
# [66/100] Processing paper: Formal Specifications from Natural Language...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=3: reject, not good enough
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [67/100] Processing paper: Scalable 3D Object-centric Learning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=3: reject, not good enough
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [68/100] Processing paper: Scalable Multi-Modal Continual Meta-Learning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=5: marginally below the acceptance threshold
#
# [69/100] Processing paper: EPISODE: Episodic Gradient Clipping with Periodic Resampled ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [70/100] Processing paper: An Experiment Design Paradigm using Joint Feature Selection ...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=3: reject, not good enough
#
# [71/100] Processing paper: SwinZS3: Zero-Shot Semantic Segmentation with a Swin Transfo...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=1: strong reject
#       Review 3: rating=3: reject, not good enough
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [72/100] Processing paper: Reinforcement Logic Rule Learning for Temporal Point Process...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=3: reject, not good enough
#
# [73/100] Processing paper: SoftMatch: Addressing the Quantity-Quality Tradeoff in Semi-...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=8: accept, good paper
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [74/100] Processing paper: Classically Approximating Variational Quantum Machine Learni...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=8: accept, good paper
#
# [75/100] Processing paper: Topology-aware Robust Optimization for Out-of-Distribution G...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#       Review 5: rating=6: marginally above the acceptance threshold
#
# [76/100] Processing paper: $z$-SignFedAvg: A Unified  Stochastic Sign-based Compression...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=3: reject, not good enough
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#
# [77/100] Processing paper: Multi-Behavior Dynamic Contrastive Learning for Recommendati...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=10: strong accept, should be highlighted at the conference
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [78/100] Processing paper: Exploring Neural Network Representational Similarity using F...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=6: marginally above the acceptance threshold
#
# [79/100] Processing paper: Generative Model Based Noise Robust Training for Unsupervise...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=3: reject, not good enough
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [80/100] Processing paper: Mutual Information Regularized Offline Reinforcement Learnin...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=3: reject, not good enough
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [81/100] Processing paper: Closed Boundary Learning for NLP Classification Tasks with t...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#
# [82/100] Processing paper: Complexity-Based Prompting for Multi-step Reasoning...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=3: reject, not good enough
#       Review 3: rating=8: accept, good paper
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [83/100] Processing paper: CRISP: Curriculum inducing Primitive Informed Subgoal Predic...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=5: marginally below the acceptance threshold
#
# [84/100] Processing paper: Approximated Anomalous Diffusion: Gaussian Mixture Score-bas...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=3: reject, not good enough
#       Review 2: rating=8: accept, good paper
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [85/100] Processing paper: Data-Efficient and Interpretable Tabular Anomaly Detection...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [86/100] Processing paper: Distribution Shift Detection for Deep Neural Networks...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [87/100] Processing paper: Continuized Acceleration for Quasar Convex Functions  in Non...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=8: accept, good paper
#       Review 4: rating=8: accept, good paper
#
# [88/100] Processing paper: Light Sampling Field and BRDF Representation for Physically-...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=8: accept, good paper
#       Review 3: rating=3: reject, not good enough
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [89/100] Processing paper: Conformal Prediction is Robust to Label Noise...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=3: reject, not good enough
#       Review 4: rating=5: marginally below the acceptance threshold
#
# [90/100] Processing paper: Simple initialization and parametrization of sinusoidal netw...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=8: accept, good paper
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=8: accept, good paper
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [91/100] Processing paper: Temporal Dynamics Aware Adversarial Attacks On Discrete-Time...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 5 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=1: strong reject
#       Review 5: rating=5: marginally below the acceptance threshold
#
# [92/100] Processing paper: Accurate Neural Training with 4-bit Matrix Multiplications a...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=8: accept, good paper
#       Review 3: rating=6: marginally above the acceptance threshold
#
# [93/100] Processing paper: Quantum Fourier Networks for solving Parametric PDEs...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=3: reject, not good enough
#
# [94/100] Processing paper: Learning Harmonic Molecular Representations on Riemannian Ma...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
# Retrying request: GET /notes?forum=ySCL-NG_I3&limit=1000&after=-4Qd06vUEUI&sort=id, response: <urllib3.response.HTTPResponse object at 0x7c63adea36d0>, error: None
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=8: accept, good paper
#
# [95/100] Processing paper: Accelerated Training via Principled Methods for Incrementall...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 3 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=5: marginally below the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#
# [96/100] Processing paper: Landscape Learning for Neural Network Inversion...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=5: marginally below the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [97/100] Processing paper: Rethinking skip connection model as a learnable Markov chain...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# [98/100] Processing paper: Robustness Evaluation Using Local Substitute Networks...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=3: reject, not good enough
#       Review 2: rating=1: strong reject
#       Review 3: rating=3: reject, not good enough
#       Review 4: rating=3: reject, not good enough
#
# [99/100] Processing paper: Removing Structured Noise with Diffusion Models...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=5: marginally below the acceptance threshold
#       Review 2: rating=8: accept, good paper
#       Review 3: rating=3: reject, not good enough
#       Review 4: rating=3: reject, not good enough
#
# [100/100] Processing paper: Constructive TT-representation of the tensors given as index...
#   - Downloading PDF...
#     ✓ PDF saved
#   - Fetching reviews...
#     Found 4 official reviews
#       Review 1: rating=6: marginally above the acceptance threshold
#       Review 2: rating=6: marginally above the acceptance threshold
#       Review 3: rating=6: marginally above the acceptance threshold
#       Review 4: rating=6: marginally above the acceptance threshold
#
# ================================================================================
# Saving data to CSV: /content/drive/MyDrive/Notebooks/AI_review/iclr_2023_data/iclr_2023_reviews.csv
# ✓ Successfully saved 378 records
# ✓ PDFs are saved in: /content/drive/MyDrive/Notebooks/AI_review/iclr_2023_data/pdfs
# ✓ CSV file saved at: /content/drive/MyDrive/Notebooks/AI_review/iclr_2023_data/iclr_2023_reviews.csv
# ================================================================================
#
# ================================================================================
# All requested years downloaded successfully!
# Files saved to Google Drive: /content/drive/MyDrive/Notebooks/AI_review
# ================================================================================
